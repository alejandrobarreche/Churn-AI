# %%
import pandas as pd

# %%
pred = pd.read_csv('data/warehouse/new_customers_predictions.csv')

# %%
print(pred['churn_proba'].sort_values(ascending=False).head(10))
# Out:
# 1810    0.398063
# 2562    0.398063
# 6603    0.311042
# 7552    0.311042
# 5011    0.310081
# 6276    0.293222
# 2306    0.291246
# 105     0.288536
# 4058    0.285094
# 4664    0.284015
# Name: churn_proba, dtype: float64

# %%
acciones = pd.read_csv('data/warehouse/clientes_acciones_comerciales.csv')

# %%
print(acciones['p_churn'].sort_values(ascending=False).head(10))
# Out:
# 7774    0.398063
# 7773    0.398063
# 7772    0.311042
# 7771    0.311042
# 7770    0.310081
# 7767    0.293222
# 7769    0.291246
# 7766    0.288536
# 7765    0.285094
# 7764    0.284015
# Name: p_churn, dtype: float64
